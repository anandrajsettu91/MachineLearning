# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('CKD.csv')
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#            age         bp   al   su         bgr          bu        sc  \
# 0     2.000000  76.459948  3.0  0.0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948  2.0  0.0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948  1.0  0.0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948  1.0  0.0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000  0.0  0.0  148.112676   25.000000  0.600000
# ..         ...        ...  ...  ...         ...         ...       ...
# 394  51.492308  70.000000  0.0  0.0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000  0.0  2.0  220.000000   68.000000  2.800000
# 396  51.492308  70.000000  3.0  0.0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000  0.0  0.0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000  0.0  0.0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo  ...  pc_normal  pcc_present  ba_present  \
# 0    137.528754  4.627244  12.518156  ...      False        False       False
# 1    137.528754  4.627244  10.700000  ...       True        False       False
# 2    138.000000  4.400000  12.000000  ...       True        False       False
# 3    138.000000  3.200000   8.100000  ...       True        False       False
# 4    137.528754  4.627244  11.800000  ...       True        False       False
# ..          ...       ...        ...  ...        ...          ...         ...
# 394  139.000000  3.700000  12.500000  ...       True        False       False
# 395  137.528754  4.627244   8.700000  ...       True        False       False
# 396  134.000000  2.700000   9.100000  ...       True        False       False
# 397  142.000000  5.500000   8.500000  ...       True        False       False
# 398  140.000000  5.000000  16.300000  ...       True        False       False
#
#      htn_yes  dm_yes  cad_yes  appet_yes  pe_yes  ane_yes  classification_yes
# 0      False   False    False       True    True    False                True
# 1      False   False    False       True   False    False                True
# 2      False   False    False       True   False    False                True
# 3      False   False    False       True   False     True                True
# 4      False   False    False       True   False    False                True
# ..       ...     ...      ...        ...     ...      ...                 ...
# 394    False   False    False       True   False    False                True
# 395     True    True    False       True   False     True                True
# 396     True    True    False      False   False    False                True
# 397     True    True    False       True   False     True                True
# 398    False   False    False       True   False    False               False
#
# [399 rows x 28 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
#        'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
#        'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
#        'appet_yes', 'pe_yes', 'ane_yes', 'classification_yes'],
#       dtype='object')

# %%
indep=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]
dep=dataset['classification_yes']

# %%
dataset['classification_yes'].value_counts()
# Out:
# classification_yes
# True     249
# False    150
# Name: count, dtype: int64

# %%
#split into train and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(indep, dep, test_size=1/3, random_state=0)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
param_grid={'kernel':['linear', 'rbf', 'sigmoid'],
            'gamma':['auto', 'scale'],
            'C':[10,100,1000,2000,3000]}
grid=GridSearchCV(SVC(probability=True), param_grid, refit=True, verbose=3, cv=5, n_jobs=-1, scoring='f1_weighted')
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# GridSearchCV(cv=5, estimator=SVC(probability=True), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['linear', 'rbf', 'sigmoid']},
#              scoring='f1_weighted', verbose=3)

# %%
re=grid.cv_results_
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0      151.950130     68.078396         0.009789        0.000831       10
# 1        0.059126      0.002988         0.012956        0.000325       10
# 2        0.023603      0.002569         0.010136        0.000794       10
# 3      175.849450     82.163068         0.010971        0.004173       10
# 4        0.046688      0.010928         0.014899        0.006710       10
# 5        0.029343      0.002742         0.010681        0.001767       10
# 6      192.132120     91.336648         0.009152        0.000422      100
# 7        0.062488      0.001954         0.012656        0.000520      100
# 8        0.020613      0.000392         0.010965        0.001142      100
# 9      214.299742    115.588487         0.009888        0.001293      100
# 10       0.038192      0.001415         0.012578        0.003077      100
# 11       0.022494      0.002217         0.010253        0.000782      100
# 12     249.294575    155.523371         0.009219        0.001087     1000
# 13       0.062148      0.003099         0.012852        0.000695     1000
# 14       0.024479      0.004337         0.010450        0.001406     1000
# 15     230.136451    106.977905         0.008804        0.000409     1000
# 16       0.047083      0.002226         0.010053        0.000151     1000
# 17       0.022338      0.001537         0.010819        0.001282     1000
# 18     391.856667    270.904676         0.009206        0.000926     2000
# 19       0.061699      0.002858         0.012292        0.000820     2000
# 20       0.023318      0.002277         0.009895        0.001348     2000
# 21     349.877090    231.312075         0.010099        0.001716     2000
# 22       0.075788      0.012619         0.013464        0.000740     2000
# 23       0.026410      0.002827         0.012240        0.002181     2000
# 24     306.018784    231.745506         0.009665        0.000780     3000
# 25       0.060993      0.002417         0.013239        0.002033     3000
# 26       0.020967      0.001384         0.010863        0.001016     3000
# 27     304.870722    219.814908         0.009309        0.000885     3000
# 28       0.092563      0.018230         0.012778        0.003362     3000
# 29       0.019590      0.001883         0.009372        0.000581     3000
#
#    param_gamma param_kernel  \
# 0         auto       linear
# 1         auto          rbf
# 2         auto      sigmoid
# 3        scale       linear
# 4        scale          rbf
# 5        scale      sigmoid
# 6         auto       linear
# 7         auto          rbf
# 8         auto      sigmoid
# 9        scale       linear
# 10       scale          rbf
# 11       scale      sigmoid
# 12        auto       linear
# 13        auto          rbf
# 14        auto      sigmoid
# 15       scale       linear
# 16       scale          rbf
# 17       scale      sigmoid
# 18        auto       linear
# 19        auto          rbf
# 20        auto      sigmoid
# 21       scale       linear
# 22       scale          rbf
# 23       scale      sigmoid
# 24        auto       linear
# 25        auto          rbf
# 26        auto      sigmoid
# 27       scale       linear
# 28       scale          rbf
# 29       scale      sigmoid
#
#                                                params  split0_test_score  \
# 0      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.963284
# 1         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           0.486532
# 2     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.486532
# 3     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.963284
# 4        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}           0.486532
# 5    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.475244
# 6     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.963284
# 7        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.486532
# 8    {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.486532
# 9    {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.963284
# 10      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.827136
# 11  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.475244
# 12   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.963284
# 13      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.486532
# 14  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.486532
# 15  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.963284
# 16     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.890467
# 17  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.475244
# 18   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.963284
# 19      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.486532
# 20  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.486532
# 21  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.963284
# 22     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.908501
# 23  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...           0.475244
# 24   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.963284
# 25      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.486532
# 26  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.486532
# 27  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.963284
# 28     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.908501
# 29  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...           0.475244
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.981014           0.925524           0.942332
# 1            0.501410           0.477841           0.477841
# 2            0.501410           0.477841           0.477841
# 3            0.981014           0.925524           0.942332
# 4            0.507851           0.477841           0.477841
# 5            0.530829           0.573705           0.563713
# 6            0.981014           0.925524           0.943093
# 7            0.501410           0.477841           0.477841
# 8            0.501410           0.477841           0.477841
# 9            0.981014           0.925524           0.943093
# 10           0.665930           0.673215           0.676696
# 11           0.497448           0.541912           0.563713
# 12           0.981014           0.925524           0.943093
# 13           0.501410           0.477841           0.477841
# 14           0.501410           0.477841           0.477841
# 15           0.981014           0.925524           0.943093
# 16           0.869709           0.739869           0.887719
# 17           0.497448           0.541912           0.563713
# 18           0.981014           0.925524           0.943093
# 19           0.501410           0.477841           0.477841
# 20           0.501410           0.477841           0.477841
# 21           0.981014           0.925524           0.943093
# 22           0.906166           0.814192           0.868519
# 23           0.497448           0.541912           0.563713
# 24           0.981014           0.925524           0.943093
# 25           0.501410           0.477841           0.477841
# 26           0.501410           0.477841           0.477841
# 27           0.981014           0.925524           0.943093
# 28           0.906166           0.814192           0.829279
# 29           0.497448           0.541912           0.563713
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.981031         0.958637        0.021845                7
# 1            0.477841         0.484293        0.009196               21
# 2            0.477841         0.484293        0.009196               21
# 3            0.981031         0.958637        0.021845                7
# 4            0.477841         0.485581        0.011632               20
# 5            0.628418         0.554382        0.050516               18
# 6            0.962264         0.955036        0.019019                9
# 7            0.477841         0.484293        0.009196               21
# 8            0.477841         0.484293        0.009196               21
# 9            0.962264         0.955036        0.019019                9
# 10           0.820320         0.732659        0.074470               14
# 11           0.689967         0.553657        0.075003               19
# 12           0.981031         0.958789        0.021734                1
# 13           0.477841         0.484293        0.009196               21
# 14           0.477841         0.484293        0.009196               21
# 15           0.981031         0.958789        0.021734                1
# 16           0.865441         0.850641        0.056239               13
# 17           0.753403         0.566344        0.098631               15
# 18           0.981031         0.958789        0.021734                1
# 19           0.477841         0.484293        0.009196               21
# 20           0.477841         0.484293        0.009196               21
# 21           0.981031         0.958789        0.021734                1
# 22           0.905155         0.880507        0.036307               11
# 23           0.753403         0.566344        0.098631               15
# 24           0.981031         0.958789        0.021734                1
# 25           0.477841         0.484293        0.009196               21
# 26           0.477841         0.484293        0.009196               21
# 27           0.981031         0.958789        0.021734                1
# 28           0.905155         0.872658        0.041865               12
# 29           0.753403         0.566344        0.098631               15

# %%
#best parameters after tuning
print('The best parameters for SVC',grid.best_params_)
grid_predictions=grid.predict(X_test)
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,grid_predictions)
print('The confusion matrix:\n',cm)
from sklearn.metrics import classification_report
clf_report=classification_report(y_test,grid_predictions)
print('The classification report:\n',clf_report)
# Out:
# The best parameters for SVC {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}
# The confusion matrix:
#  [[49  2]
#  [ 1 81]]
# The classification report:
#                precision    recall  f1-score   support
#
#        False       0.98      0.96      0.97        51
#         True       0.98      0.99      0.98        82
#
#     accuracy                           0.98       133
#    macro avg       0.98      0.97      0.98       133
# weighted avg       0.98      0.98      0.98       133

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# np.float64(0.9990435198469632)
